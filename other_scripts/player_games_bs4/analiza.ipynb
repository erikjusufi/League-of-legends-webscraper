# %%
import pandas as pd

# %%
dt = pd.read_csv("../player_stats/pro_players.csv")
dt.head(10)
# Out:
#    Unnamed: 0    id          name             real_name win_per  wins  losses  \
# 0           0  4483      Akaadian  Matthew Higginbotham     41%     7      10
# 1           1  4485      Aphromoo         Zaqueri Black      0%     0       1
# 2           2  4500         Armut      İrfan Berk Tükek     48%    83      89
# 3           3  4506      Bjergsen           Søren Bjerg     57%    34      26
# 4           4  4507          Bang     Bae Jun-sik (배준식)     44%    24      30
# 5           5  4509           Bdd   Kwak Bo-seong (곽보성)      0%     0       1
# 6           6  4514        Boxbox          Albert Zheng     31%    11      24
# 7           7  4521        Broxah   Mads Brock-Pedersen     53%    48      43
# 8           8  4527  Broken Blade          Sergen Çelik     64%    47      26
# 9           9  4532          Caps        Rasmus Winther     55%   142     115
#
#    num_of_games            rank  kills  deaths  assists       kda server
# ...
